# %% [markdown]
# Let's look at a simple example of using transfer learning to build upon an imagenet neural network. We will begin by training a neural network for Fisher's Iris Dataset. This network takes four measurements and classifies each observation into three iris species. However, what if later we received a data set that included the four measurements, plus a cost as the target? This dataset does not contain the species; as a result, it uses the same four inputs as the base model we just trained.
#
# We can take our previously trained iris network and transfer the weights to a new neural network that will learn to predict the cost through transfer learning. Also of note, the original neural network was a classification network, yet we now use it to build a regression neural network. Such a transformation is common for transfer learning. As a reference point, I randomly created this iris cost dataset

# %%
import pandas as pd
import io
import requests
import numpy as np
from sklearn import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping

df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/iris.csv", 
    na_values=['NA', '?'])

# Convert to numpy - Classification
x = df[['sepal_l', 'sepal_w', 'petal_l', 'petal_w']].values
dummies = pd.get_dummies(df['species']) # Classification
species = dummies.columns
y = dummies.values


# Build neural network
model = Sequential()
model.add(Dense(50, input_dim=x.shape[1], activation='relu')) # Hidden 1
model.add(Dense(25, activation='relu')) # Hidden 2
model.add(Dense(y.shape[1],activation='softmax')) # Output

model.compile(loss='categorical_crossentropy', optimizer='adam')
model.fit(x,y,verbose=2,epochs=100)
# Out:
# Epoch 1/100
# 5/5 - 1s - loss: 0.9395 - 578ms/epoch - 116ms/step
# Epoch 2/100
# 5/5 - 0s - loss: 0.8442 - 12ms/epoch - 2ms/step
# Epoch 3/100
# 5/5 - 0s - loss: 0.7790 - 11ms/epoch - 2ms/step
# Epoch 4/100
# 5/5 - 0s - loss: 0.7190 - 9ms/epoch - 2ms/step
# Epoch 5/100
# 5/5 - 0s - loss: 0.6685 - 11ms/epoch - 2ms/step
# Epoch 6/100
# 5/5 - 0s - loss: 0.6252 - 12ms/epoch - 2ms/step
# Epoch 7/100
# 5/5 - 0s - loss: 0.5894 - 13ms/epoch - 3ms/step
# Epoch 8/100
# 5/5 - 0s - loss: 0.5588 - 10ms/epoch - 2ms/step
# Epoch 9/100
# 5/5 - 0s - loss: 0.5289 - 9ms/epoch - 2ms/step
# Epoch 10/100
# 5/5 - 0s - loss: 0.5050 - 9ms/epoch - 2ms/step
# Epoch 11/100
# 5/5 - 0s - loss: 0.4828 - 9ms/epoch - 2ms/step
# Epoch 12/100
# 5/5 - 0s - loss: 0.4610 - 8ms/epoch - 2ms/step
# Epoch 13/100
# 5/5 - 0s - loss: 0.4352 - 9ms/epoch - 2ms/step
# Epoch 14/100
# 5/5 - 0s - loss: 0.4137 - 8ms/epoch - 2ms/step
# Epoch 15/100
# 5/5 - 0s - loss: 0.3908 - 8ms/epoch - 2ms/step
# Epoch 16/100
# 5/5 - 0s - loss: 0.3705 - 9ms/epoch - 2ms/step
# Epoch 17/100
# 5/5 - 0s - loss: 0.3459 - 10ms/epoch - 2ms/step
# Epoch 18/100
# 5/5 - 0s - loss: 0.3301 - 9ms/epoch - 2ms/step
# Epoch 19/100
# 5/5 - 0s - loss: 0.3109 - 8ms/epoch - 2ms/step
# Epoch 20/100
# 5/5 - 0s - loss: 0.2987 - 9ms/epoch - 2ms/step
# Epoch 21/100
# 5/5 - 0s - loss: 0.2838 - 9ms/epoch - 2ms/step
# Epoch 22/100
# 5/5 - 0s - loss: 0.2730 - 11ms/epoch - 2ms/step
# Epoch 23/100
# 5/5 - 0s - loss: 0.2590 - 11ms/epoch - 2ms/step
# Epoch 24/100
# 5/5 - 0s - loss: 0.2489 - 10ms/epoch - 2ms/step
# Epoch 25/100
# 5/5 - 0s - loss: 0.2384 - 16ms/epoch - 3ms/step
# Epoch 26/100
# 5/5 - 0s - loss: 0.2286 - 10ms/epoch - 2ms/step
# Epoch 27/100
# 5/5 - 0s - loss: 0.2188 - 11ms/epoch - 2ms/step
# Epoch 28/100
# 5/5 - 0s - loss: 0.2105 - 11ms/epoch - 2ms/step
# Epoch 29/100
# 5/5 - 0s - loss: 0.2023 - 12ms/epoch - 2ms/step
# Epoch 30/100
# 5/5 - 0s - loss: 0.1953 - 14ms/epoch - 3ms/step
# Epoch 31/100
# 5/5 - 0s - loss: 0.1888 - 9ms/epoch - 2ms/step
# Epoch 32/100
# 5/5 - 0s - loss: 0.1807 - 10ms/epoch - 2ms/step
# Epoch 33/100
# 5/5 - 0s - loss: 0.1799 - 9ms/epoch - 2ms/step
# Epoch 34/100
# 5/5 - 0s - loss: 0.1808 - 10ms/epoch - 2ms/step
# Epoch 35/100
# 5/5 - 0s - loss: 0.1685 - 10ms/epoch - 2ms/step
# Epoch 36/100
# 5/5 - 0s - loss: 0.1630 - 11ms/epoch - 2ms/step
# Epoch 37/100
# 5/5 - 0s - loss: 0.1531 - 10ms/epoch - 2ms/step
# Epoch 38/100
# 5/5 - 0s - loss: 0.1555 - 10ms/epoch - 2ms/step
# Epoch 39/100
# 5/5 - 0s - loss: 0.1454 - 12ms/epoch - 2ms/step
# Epoch 40/100
# 5/5 - 0s - loss: 0.1461 - 13ms/epoch - 3ms/step
# Epoch 41/100
# 5/5 - 0s - loss: 0.1408 - 9ms/epoch - 2ms/step
# Epoch 42/100
# 5/5 - 0s - loss: 0.1366 - 9ms/epoch - 2ms/step
# Epoch 43/100
# 5/5 - 0s - loss: 0.1333 - 9ms/epoch - 2ms/step
# Epoch 44/100
# 5/5 - 0s - loss: 0.1300 - 10ms/epoch - 2ms/step
# Epoch 45/100
# 5/5 - 0s - loss: 0.1317 - 10ms/epoch - 2ms/step
# Epoch 46/100
# 5/5 - 0s - loss: 0.1250 - 12ms/epoch - 2ms/step
# Epoch 47/100
# 5/5 - 0s - loss: 0.1225 - 11ms/epoch - 2ms/step
# Epoch 48/100
# 5/5 - 0s - loss: 0.1213 - 12ms/epoch - 2ms/step
# Epoch 49/100
# 5/5 - 0s - loss: 0.1172 - 10ms/epoch - 2ms/step
# Epoch 50/100
# 5/5 - 0s - loss: 0.1157 - 10ms/epoch - 2ms/step
# Epoch 51/100
# 5/5 - 0s - loss: 0.1145 - 10ms/epoch - 2ms/step
# Epoch 52/100
# 5/5 - 0s - loss: 0.1118 - 9ms/epoch - 2ms/step
# Epoch 53/100
# 5/5 - 0s - loss: 0.1094 - 11ms/epoch - 2ms/step
# Epoch 54/100
# 5/5 - 0s - loss: 0.1083 - 9ms/epoch - 2ms/step
# Epoch 55/100
# 5/5 - 0s - loss: 0.1064 - 10ms/epoch - 2ms/step
# Epoch 56/100
# 5/5 - 0s - loss: 0.1067 - 10ms/epoch - 2ms/step
# Epoch 57/100
# 5/5 - 0s - loss: 0.1026 - 10ms/epoch - 2ms/step
# Epoch 58/100
# 5/5 - 0s - loss: 0.1008 - 10ms/epoch - 2ms/step
# Epoch 59/100
# 5/5 - 0s - loss: 0.1024 - 11ms/epoch - 2ms/step
# Epoch 60/100
# 5/5 - 0s - loss: 0.0988 - 11ms/epoch - 2ms/step
# Epoch 61/100
# 5/5 - 0s - loss: 0.0963 - 13ms/epoch - 3ms/step
# Epoch 62/100
# 5/5 - 0s - loss: 0.0950 - 11ms/epoch - 2ms/step
# Epoch 63/100
# 5/5 - 0s - loss: 0.0942 - 12ms/epoch - 2ms/step
# Epoch 64/100
# 5/5 - 0s - loss: 0.0940 - 11ms/epoch - 2ms/step
# Epoch 65/100
# 5/5 - 0s - loss: 0.0914 - 10ms/epoch - 2ms/step
# Epoch 66/100
# 5/5 - 0s - loss: 0.0921 - 13ms/epoch - 3ms/step
# Epoch 67/100
# 5/5 - 0s - loss: 0.0928 - 11ms/epoch - 2ms/step
# Epoch 68/100
# 5/5 - 0s - loss: 0.0900 - 11ms/epoch - 2ms/step
# Epoch 69/100
# 5/5 - 0s - loss: 0.0883 - 11ms/epoch - 2ms/step
# Epoch 70/100
# 5/5 - 0s - loss: 0.0881 - 10ms/epoch - 2ms/step
# Epoch 71/100
# 5/5 - 0s - loss: 0.0861 - 10ms/epoch - 2ms/step
# Epoch 72/100
# 5/5 - 0s - loss: 0.0860 - 10ms/epoch - 2ms/step
# Epoch 73/100
# 5/5 - 0s - loss: 0.0878 - 9ms/epoch - 2ms/step
# Epoch 74/100
# 5/5 - 0s - loss: 0.0854 - 9ms/epoch - 2ms/step
# Epoch 75/100
# 5/5 - 0s - loss: 0.0835 - 9ms/epoch - 2ms/step
# Epoch 76/100
# 5/5 - 0s - loss: 0.0893 - 10ms/epoch - 2ms/step
# Epoch 77/100
# 5/5 - 0s - loss: 0.0817 - 10ms/epoch - 2ms/step
# Epoch 78/100
# 5/5 - 0s - loss: 0.0822 - 11ms/epoch - 2ms/step
# Epoch 79/100
# 5/5 - 0s - loss: 0.0822 - 12ms/epoch - 2ms/step
# Epoch 80/100
# 5/5 - 0s - loss: 0.0796 - 12ms/epoch - 2ms/step
# Epoch 81/100
# 5/5 - 0s - loss: 0.0818 - 12ms/epoch - 2ms/step
# Epoch 82/100
# 5/5 - 0s - loss: 0.0788 - 12ms/epoch - 2ms/step
# Epoch 83/100
# 5/5 - 0s - loss: 0.0776 - 11ms/epoch - 2ms/step
# Epoch 84/100
# 5/5 - 0s - loss: 0.0766 - 11ms/epoch - 2ms/step
# Epoch 85/100
# 5/5 - 0s - loss: 0.0798 - 13ms/epoch - 3ms/step
# Epoch 86/100
# 5/5 - 0s - loss: 0.0765 - 11ms/epoch - 2ms/step
# Epoch 87/100
# 5/5 - 0s - loss: 0.0758 - 12ms/epoch - 2ms/step
# Epoch 88/100
# 5/5 - 0s - loss: 0.0760 - 12ms/epoch - 2ms/step
# Epoch 89/100
# 5/5 - 0s - loss: 0.0771 - 12ms/epoch - 2ms/step
# Epoch 90/100
# 5/5 - 0s - loss: 0.0751 - 18ms/epoch - 4ms/step
# Epoch 91/100
# 5/5 - 0s - loss: 0.0754 - 14ms/epoch - 3ms/step
# Epoch 92/100
# 5/5 - 0s - loss: 0.0738 - 11ms/epoch - 2ms/step
# Epoch 93/100
# 5/5 - 0s - loss: 0.0744 - 10ms/epoch - 2ms/step
# Epoch 94/100
# 5/5 - 0s - loss: 0.0731 - 11ms/epoch - 2ms/step
# Epoch 95/100
# 5/5 - 0s - loss: 0.0740 - 9ms/epoch - 2ms/step
# Epoch 96/100
# 5/5 - 0s - loss: 0.0719 - 12ms/epoch - 2ms/step
# Epoch 97/100
# 5/5 - 0s - loss: 0.0714 - 13ms/epoch - 3ms/step
# Epoch 98/100
# 5/5 - 0s - loss: 0.0734 - 10ms/epoch - 2ms/step
# Epoch 99/100
# 5/5 - 0s - loss: 0.0727 - 9ms/epoch - 2ms/step
# Epoch 100/100
# 5/5 - 0s - loss: 0.0692 - 9ms/epoch - 2ms/step

# %% [markdown]
# To keep this example simple, we are not setting aside a validation set. The goal of this example is to show how to create a multi-layer neural network, where we transfer the weights to another network. We begin by evaluating the accuracy of the network on the training set.

# %%
from sklearn.metrics import accuracy_score
pred = model.predict(x)
predict_classes = np.argmax(pred,axis=1)
expected_classes = np.argmax(y,axis=1)
correct = accuracy_score(expected_classes,predict_classes)
print(f"Training Accuracy: {correct}")
# Out:
# Training Accuracy: 0.98

# %% [markdown]
# # Create a New Iris Network
# Now that we've trained a neural network on the iris dataset, we can transfer the knowledge of this neural network to other neural networks. It is possible to create a new neural network from some or all of the layers of this neural network. We will create a new neural network that is essentially a clone of the first neural network to demonstrate the technique. We now transfer all of the layers from the original neural network into the new one.

# %%
model2 = Sequential()
for layer in model.layers:
    model2.add(layer)
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                250
#
#  dense_1 (Dense)             (None, 25)                1275
#
#  dense_2 (Dense)             (None, 3)                 78
#
# =================================================================
# Total params: 1,603
# Trainable params: 1,603
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Transfering to a Regression Network
#
# The Iris Cost Dataset has measurements for samples of these flowers that conform to the predictors contained in the original iris dataset: sepal width, sepal length, petal width, and petal length.

# %%
df_cost = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/iris_cost.csv", 
    na_values=['NA', '?'])

df_cost
# Out:
#      sepal_l  sepal_w  petal_l  petal_w    cost
# 0        7.8      3.0      6.2      2.0  10.740
# 1        5.0      2.2      1.7      1.5   2.710
# 2        6.9      2.6      3.7      1.4   4.624
# 3        5.9      2.2      3.7      2.4   6.558
# 4        5.1      3.9      6.8      0.7   7.395
# ..       ...      ...      ...      ...     ...
# 245      4.7      2.1      4.0      2.3   5.721
# 246      7.2      3.0      4.3      1.1   5.266
# 247      6.6      3.4      4.6      1.4   5.776
# 248      5.7      3.7      3.1      0.4   2.233
# 249      7.6      4.0      5.1      1.4   7.508
#
# [250 rows x 5 columns]

# %% [markdown]
# For transfer learning to be effective, the input for the newly trained neural network most closely conforms to the first neural network we transfer.
#
# We will strip away the last output layer that contains the softmax activation function that performs this final classification. We will create a new output layer that will output the cost prediction. We will only train the weights in this new layer. We will mark the first two layers as non-trainable. The hope is that the first few layers have learned to abstract the raw input data in a way that is also helpful to the new neural network. This process is accomplished by looping over the first few layers and copying them to the new neural network. We output a summary of the new neural network to verify that Keras stripped the previous output layer.

# %%
model3 = Sequential()
for i in range(2):
    layer = model.layers[i]
    layer.trainable = False
    model3.add(layer)
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                250
#
#  dense_1 (Dense)             (None, 25)                1275
#
# =================================================================
# Total params: 1,525
# Trainable params: 0
# Non-trainable params: 1,525
# _________________________________________________________________

# %%
model3.add(Dense(1)) # Output

model3.compile(loss='mean_squared_error', optimizer='adam')
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                250
#
#  dense_1 (Dense)             (None, 25)                1275
#
#  dense_3 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 1,551
# Trainable params: 26
# Non-trainable params: 1,525
# _________________________________________________________________

# %%
# Convert to numpy - Classification
x = df_cost[['sepal_l', 'sepal_w', 'petal_l', 'petal_w']].values
y = df_cost.cost.values

# Train the last layer of the network
model3.fit(x,y,verbose=2,epochs=100)
# Out:
# Epoch 1/100
# 8/8 - 1s - loss: 60.2365 - 624ms/epoch - 78ms/step
# Epoch 2/100
# 8/8 - 0s - loss: 57.2644 - 24ms/epoch - 3ms/step
# Epoch 3/100
# 8/8 - 0s - loss: 54.3914 - 23ms/epoch - 3ms/step
# Epoch 4/100
# 8/8 - 0s - loss: 51.5861 - 42ms/epoch - 5ms/step
# Epoch 5/100
# 8/8 - 0s - loss: 48.9371 - 24ms/epoch - 3ms/step
# Epoch 6/100
# 8/8 - 0s - loss: 46.4227 - 23ms/epoch - 3ms/step
# Epoch 7/100
# 8/8 - 0s - loss: 43.9635 - 25ms/epoch - 3ms/step
# Epoch 8/100
# 8/8 - 0s - loss: 41.6181 - 26ms/epoch - 3ms/step
# Epoch 9/100
# 8/8 - 0s - loss: 39.4982 - 34ms/epoch - 4ms/step
# Epoch 10/100
# 8/8 - 0s - loss: 37.3114 - 21ms/epoch - 3ms/step
# Epoch 11/100
# 8/8 - 0s - loss: 35.3462 - 24ms/epoch - 3ms/step
# Epoch 12/100
# 8/8 - 0s - loss: 33.4820 - 24ms/epoch - 3ms/step
# Epoch 13/100
# 8/8 - 0s - loss: 31.6481 - 23ms/epoch - 3ms/step
# Epoch 14/100
# 8/8 - 0s - loss: 29.9383 - 17ms/epoch - 2ms/step
# Epoch 15/100
# 8/8 - 0s - loss: 28.3541 - 22ms/epoch - 3ms/step
# Epoch 16/100
# 8/8 - 0s - loss: 26.8030 - 37ms/epoch - 5ms/step
# Epoch 17/100
# 8/8 - 0s - loss: 25.3442 - 26ms/epoch - 3ms/step
# Epoch 18/100
# 8/8 - 0s - loss: 23.9870 - 27ms/epoch - 3ms/step
# Epoch 19/100
# 8/8 - 0s - loss: 22.6929 - 22ms/epoch - 3ms/step
# Epoch 20/100
# 8/8 - 0s - loss: 21.4765 - 24ms/epoch - 3ms/step
# Epoch 21/100
# 8/8 - 0s - loss: 20.3240 - 25ms/epoch - 3ms/step
# Epoch 22/100
# 8/8 - 0s - loss: 19.2363 - 32ms/epoch - 4ms/step
# Epoch 23/100
# 8/8 - 0s - loss: 18.2353 - 26ms/epoch - 3ms/step
# Epoch 24/100
# 8/8 - 0s - loss: 17.2774 - 21ms/epoch - 3ms/step
# Epoch 25/100
# 8/8 - 0s - loss: 16.3531 - 24ms/epoch - 3ms/step
# Epoch 26/100
# 8/8 - 0s - loss: 15.5253 - 19ms/epoch - 2ms/step
# Epoch 27/100
# 8/8 - 0s - loss: 14.7346 - 30ms/epoch - 4ms/step
# Epoch 28/100
# 8/8 - 0s - loss: 13.9769 - 29ms/epoch - 4ms/step
# Epoch 29/100
# 8/8 - 0s - loss: 13.2851 - 28ms/epoch - 3ms/step
# Epoch 30/100
# 8/8 - 0s - loss: 12.6457 - 28ms/epoch - 4ms/step
# Epoch 31/100
# 8/8 - 0s - loss: 12.0107 - 28ms/epoch - 4ms/step
# Epoch 32/100
# 8/8 - 0s - loss: 11.4375 - 25ms/epoch - 3ms/step
# Epoch 33/100
# 8/8 - 0s - loss: 10.8842 - 38ms/epoch - 5ms/step
# Epoch 34/100
# 8/8 - 0s - loss: 10.3813 - 32ms/epoch - 4ms/step
# Epoch 35/100
# 8/8 - 0s - loss: 9.9195 - 27ms/epoch - 3ms/step
# Epoch 36/100
# 8/8 - 0s - loss: 9.4624 - 29ms/epoch - 4ms/step
# Epoch 37/100
# 8/8 - 0s - loss: 9.0568 - 21ms/epoch - 3ms/step
# Epoch 38/100
# 8/8 - 0s - loss: 8.6667 - 23ms/epoch - 3ms/step
# Epoch 39/100
# 8/8 - 0s - loss: 8.2886 - 34ms/epoch - 4ms/step
# Epoch 40/100
# 8/8 - 0s - loss: 7.9539 - 41ms/epoch - 5ms/step
# Epoch 41/100
# 8/8 - 0s - loss: 7.6316 - 34ms/epoch - 4ms/step
# Epoch 42/100
# 8/8 - 0s - loss: 7.3273 - 22ms/epoch - 3ms/step
# Epoch 43/100
# 8/8 - 0s - loss: 7.0449 - 30ms/epoch - 4ms/step
# Epoch 44/100
# 8/8 - 0s - loss: 6.7845 - 37ms/epoch - 5ms/step
# Epoch 45/100
# 8/8 - 0s - loss: 6.5275 - 19ms/epoch - 2ms/step
# Epoch 46/100
# 8/8 - 0s - loss: 6.3042 - 13ms/epoch - 2ms/step
# Epoch 47/100
# 8/8 - 0s - loss: 6.0774 - 13ms/epoch - 2ms/step
# Epoch 48/100
# 8/8 - 0s - loss: 5.8749 - 17ms/epoch - 2ms/step
# Epoch 49/100
# 8/8 - 0s - loss: 5.6732 - 61ms/epoch - 8ms/step
# Epoch 50/100
# 8/8 - 0s - loss: 5.4935 - 20ms/epoch - 2ms/step
# Epoch 51/100
# 8/8 - 0s - loss: 5.3174 - 25ms/epoch - 3ms/step
# Epoch 52/100
# 8/8 - 0s - loss: 5.1618 - 26ms/epoch - 3ms/step
# Epoch 53/100
# 8/8 - 0s - loss: 4.9991 - 25ms/epoch - 3ms/step
# Epoch 54/100
# 8/8 - 0s - loss: 4.8595 - 24ms/epoch - 3ms/step
# Epoch 55/100
# 8/8 - 0s - loss: 4.7185 - 16ms/epoch - 2ms/step
# Epoch 56/100
# 8/8 - 0s - loss: 4.5885 - 17ms/epoch - 2ms/step
# Epoch 57/100
# 8/8 - 0s - loss: 4.4693 - 25ms/epoch - 3ms/step
# Epoch 58/100
# 8/8 - 0s - loss: 4.3490 - 27ms/epoch - 3ms/step
# Epoch 59/100
# 8/8 - 0s - loss: 4.2435 - 19ms/epoch - 2ms/step
# Epoch 60/100
# 8/8 - 0s - loss: 4.1376 - 29ms/epoch - 4ms/step
# Epoch 61/100
# 8/8 - 0s - loss: 4.0350 - 26ms/epoch - 3ms/step
# Epoch 62/100
# 8/8 - 0s - loss: 3.9463 - 27ms/epoch - 3ms/step
# Epoch 63/100
# 8/8 - 0s - loss: 3.8528 - 38ms/epoch - 5ms/step
# Epoch 64/100
# 8/8 - 0s - loss: 3.7716 - 24ms/epoch - 3ms/step
# Epoch 65/100
# 8/8 - 0s - loss: 3.6894 - 39ms/epoch - 5ms/step
# Epoch 66/100
# 8/8 - 0s - loss: 3.6157 - 44ms/epoch - 6ms/step
# Epoch 67/100
# 8/8 - 0s - loss: 3.5433 - 18ms/epoch - 2ms/step
# Epoch 68/100
# 8/8 - 0s - loss: 3.4755 - 36ms/epoch - 5ms/step
# Epoch 69/100
# 8/8 - 0s - loss: 3.4094 - 18ms/epoch - 2ms/step
# Epoch 70/100
# 8/8 - 0s - loss: 3.3474 - 27ms/epoch - 3ms/step
# Epoch 71/100
# 8/8 - 0s - loss: 3.2900 - 14ms/epoch - 2ms/step
# Epoch 72/100
# 8/8 - 0s - loss: 3.2343 - 15ms/epoch - 2ms/step
# Epoch 73/100
# 8/8 - 0s - loss: 3.1810 - 21ms/epoch - 3ms/step
# Epoch 74/100
# 8/8 - 0s - loss: 3.1290 - 14ms/epoch - 2ms/step
# Epoch 75/100
# 8/8 - 0s - loss: 3.0831 - 15ms/epoch - 2ms/step
# Epoch 76/100
# 8/8 - 0s - loss: 3.0383 - 14ms/epoch - 2ms/step
# Epoch 77/100
# 8/8 - 0s - loss: 2.9960 - 12ms/epoch - 2ms/step
# Epoch 78/100
# 8/8 - 0s - loss: 2.9522 - 17ms/epoch - 2ms/step
# Epoch 79/100
# 8/8 - 0s - loss: 2.9136 - 13ms/epoch - 2ms/step
# Epoch 80/100
# 8/8 - 0s - loss: 2.8802 - 14ms/epoch - 2ms/step
# Epoch 81/100
# 8/8 - 0s - loss: 2.8420 - 13ms/epoch - 2ms/step
# Epoch 82/100
# 8/8 - 0s - loss: 2.8093 - 14ms/epoch - 2ms/step
# Epoch 83/100
# 8/8 - 0s - loss: 2.7784 - 34ms/epoch - 4ms/step
# Epoch 84/100
# 8/8 - 0s - loss: 2.7509 - 19ms/epoch - 2ms/step
# Epoch 85/100
# 8/8 - 0s - loss: 2.7206 - 13ms/epoch - 2ms/step
# Epoch 86/100
# 8/8 - 0s - loss: 2.6938 - 14ms/epoch - 2ms/step
# Epoch 87/100
# 8/8 - 0s - loss: 2.6686 - 18ms/epoch - 2ms/step
# Epoch 88/100
# 8/8 - 0s - loss: 2.6464 - 29ms/epoch - 4ms/step
# Epoch 89/100
# 8/8 - 0s - loss: 2.6242 - 23ms/epoch - 3ms/step
# Epoch 90/100
# 8/8 - 0s - loss: 2.5988 - 17ms/epoch - 2ms/step
# Epoch 91/100
# 8/8 - 0s - loss: 2.5821 - 44ms/epoch - 6ms/step
# Epoch 92/100
# 8/8 - 0s - loss: 2.5612 - 16ms/epoch - 2ms/step
# Epoch 93/100
# 8/8 - 0s - loss: 2.5408 - 27ms/epoch - 3ms/step
# Epoch 94/100
# 8/8 - 0s - loss: 2.5242 - 18ms/epoch - 2ms/step
# Epoch 95/100
# 8/8 - 0s - loss: 2.5096 - 18ms/epoch - 2ms/step
# Epoch 96/100
# 8/8 - 0s - loss: 2.4922 - 17ms/epoch - 2ms/step
# Epoch 97/100
# 8/8 - 0s - loss: 2.4781 - 13ms/epoch - 2ms/step
# Epoch 98/100
# 8/8 - 0s - loss: 2.4631 - 21ms/epoch - 3ms/step
# Epoch 99/100
# 8/8 - 0s - loss: 2.4513 - 22ms/epoch - 3ms/step
# Epoch 100/100
# 8/8 - 0s - loss: 2.4370 - 34ms/epoch - 4ms/step

# %%
from sklearn.metrics import accuracy_score
pred = model3.predict(x)
score = np.sqrt(metrics.mean_squared_error(pred,y))
print(f"Final score (RMSE): {score}")
# Out:
# Final score (RMSE): 1.5586627443709196
